# %%
from math import exp

# Print the neurons 
def print_arr(arr):
  i=1
  for item in arr:
    print("\nNeuron ", i)
    for key in item.keys():
      if key != 'delta':
        print(key, " ", item[key])
    print()
    i+=1

# Generating the dictionary to store the neuron
def gen(arr):
	res = []
	for item in arr:
		cur = {'weights': item}
		res.append(cur)
	return res

# This function does the initialization of the network
def create_network():
  network = []
  # Each dictionary would store the weight, output and delta of a specific neuron in a layer
  # Number of entries of weights list = number of incoming weights to that neuron + 1 (bias)
  # We have 2 links per hidden neuron thus 3 entries
  hidden_wts = [[0.1, -0.2, 0.1], [0, 0.2, 0.2], [0.3, -0.4, 0.5]] 
  # We have 3 links per output neuron thus 4 entries
  ouput_wts = [[-0.4, 0.1, 0.6, -0.1], [0.2, -0.1, -0.2, 0.6]]
  hidden_layer, output_layer = gen(hidden_wts), gen(ouput_wts)
  # Appending the layers in the network
  network.append(hidden_layer)
  network.append(output_layer)
  # Inital printing of information
  print("Initial weights \n")
  print("======= Hidden layer =======")
  print_arr(hidden_layer)
  print("\n======= Output layer =======")
  print_arr(output_layer)
  print()
  # Return the network formed
  return network
 
# This would return the weighted sum of the links to a specific neuron 
# added with the bias corresponding to that neuron which acts as the linear 
# component of the inputs
def linear_component(weights, inputs):
  # Bias to a particualr neuron is the last entry of the list
  bias = weights[-1]
  sum, weighted_sum = 0, 0
  for i in range(len(weights)-1):
    # Add the respective weighted sum
    weighted_sum += weights[i] * inputs[i]
  sum = weighted_sum + bias
  # Returning the resultant sum
  return sum

# Signmoid function implementation which is the non linear
# component of the input 
def non_linear_component(activation):
	return 1.0 / (1.0 + exp(-activation))
 

def forward_propagation(network, row):
	inputs = row
  # Iterate on the layers of the network
	for layer in network:
		new_inputs = []
    # For each layer, for each neuron 
		for neuron in layer:
      # Figure out the resultant input to this neuron which is the
      # weighted sum of the links along with the bias
			activation = linear_component(neuron['weights'], inputs)
      # Now the output of this neuron is the result of the activation
      # function which is then stored as new inputs for our next layer
			neuron['output'] = non_linear_component(activation)
			new_inputs.append(neuron['output'])
		inputs = new_inputs
  # The last list produced by the iteration is the result of the output 
  # layer which is being returned from here
	return inputs

# In theory this is the partial derivative of the output for a specifc 
# neuron with respect to the net
def transfer_derivative(output):
	return output * (1.0 - output)
 
# Once the output is generated by forward propagation and error is found
# we have to minimize that error
# This is achieved by backward propagation where the weights of the links are 
# adjusted in such a manner that the resultant error is minimized 
def backward_propagate_error(network, expected):
  # We start this process from the outer most layer 
	for i in reversed(range(len(network))):
    # Extract the current layer of neurons
		current_layer = network[i]
		errors = []
    # If I am not at the last neuron
		if i != len(network)-1:
			for j in range(len(current_layer)):
				error = 0.0
        # Since the network is traversed in the backwards direction 
        # this ensures that the output layer has delta values calculated first
        # which can be used in the hidden layer for calculating errors
				for neuron in network[i + 1]:
          # j is the index of the neuron's weight in the next layer
          # which is being multiplied with the delta value of that specific neuron 
          # from the next layer
					error += (neuron['weights'][j] * neuron['delta'])
				errors.append(error)
		else:
			for j in range(len(current_layer)):
				neuron = current_layer[j]
				errors.append(neuron['output'] - expected[j])
    # Once the errors are generated for the current layer neurons, 
    # those are then multiplied by the transfer derivative function 
    # which is a part of the formula obtained by the chain rule
		for j in range(len(current_layer)):
			neuron = current_layer[j]
			neuron['delta'] = errors[j] * transfer_derivative(neuron['output'])
   
# This function is responsible for updating the weights with the error derivatives
# for a specific layer
def updation_of_weights(network, row, learning_rate):
	for i in range(len(network)):
    # Each row contains the output at the end of the row and remaining is input data
		inputs = row[:-1]
		if i != 0:
			inputs = [neuron['output'] for neuron in network[i - 1]]
		for neuron in network[i]:
			for j in range(len(inputs)):
        # As per the formula obtained by the chain rule, 
        # New weight = old weight - learning rate * partial derivative of the total error 
        # with respect to the current weight being considered
				neuron['weights'][j] -= learning_rate * neuron['delta'] * inputs[j]
			neuron['weights'][-1] -= learning_rate * neuron['delta']
 
# Now once the algoithm is in place we have to train the neural network with the dataset 
# provided in the question
def neural_network_training(network, training_dataset, learning_rate, tot_epochs, tot_outputs):
	for epoch in range(tot_epochs):
    # For each of the iterations update the weights, and find the error 
		error_sum = 0
		for row in training_dataset:
      # Output produced with the current input set 
			outputs = forward_propagation(network, row)
			expected = [0 for i in range(tot_outputs)]
      # We have the expected output for this particular input which is stored at the end
      # of this row
			expected[row[-1]] = 1
      # Error = (expected - obtained) ^ 2
      # Here we are obtaining the error for all the output neurons and adding them together 
      # to find the total error corresponding to this iteration
			error_sum += sum([(expected[i]-outputs[i])**2 for i in range(len(expected))])
      # Once total error is generated we update the weights to fit the data by the method of
      # back propagation
			backward_propagate_error(network, expected)
      # Updation of weights
			updation_of_weights(network, row, learning_rate)
		print('Epoch=%d, Learning Rate=%.3f, Error=%.3f' % (epoch+1, learning_rate, error_sum))
 
# Training dataset as per the question
dataset = [[0.6, 0.3, 1], [0.2, 0.3, 0]]
# Generating the number of distinct ouputs possible 
n_outputs = len(set([row[-1] for row in dataset]))
# Network creation
network = create_network()
# Training the neural network
neural_network_training(network, dataset, 0.1, 5000, n_outputs)

print("\nFinal weights \n")
print("======= Hidden layer =======")
print_arr(network[0])
print("\n======= Output layer =======")
print_arr(network[1])
# Out:
# Initial weights
#
# ======= Hidden layer =======
#
# Neuron  1
# weights   [0.1, -0.2, 0.1]
#
#
# Neuron  2
# weights   [0, 0.2, 0.2]
#
#
# Neuron  3
# weights   [0.3, -0.4, 0.5]
#
#
# ======= Output layer =======
#
# Neuron  1
# weights   [-0.4, 0.1, 0.6, -0.1]
#
#
# Neuron  2
# weights   [0.2, -0.1, -0.2, 0.6]
#
#
# Epoch=1, Learning Rate=0.100, Error=1.050
# Epoch=2, Learning Rate=0.100, Error=1.049
# Epoch=3, Learning Rate=0.100, Error=1.047
# Epoch=4, Learning Rate=0.100, Error=1.046
# Epoch=5, Learning Rate=0.100, Error=1.045
# Epoch=6, Learning Rate=0.100, Error=1.044
# Epoch=7, Learning Rate=0.100, Error=1.042
# Epoch=8, Learning Rate=0.100, Error=1.041
# Epoch=9, Learning Rate=0.100, Error=1.040
# Epoch=10, Learning Rate=0.100, Error=1.039
# Epoch=11, Learning Rate=0.100, Error=1.038
# Epoch=12, Learning Rate=0.100, Error=1.037
# Epoch=13, Learning Rate=0.100, Error=1.036
# Epoch=14, Learning Rate=0.100, Error=1.035
# Epoch=15, Learning Rate=0.100, Error=1.035
# Epoch=16, Learning Rate=0.100, Error=1.034
# Epoch=17, Learning Rate=0.100, Error=1.033
# Epoch=18, Learning Rate=0.100, Error=1.032
# Epoch=19, Learning Rate=0.100, Error=1.031
# Epoch=20, Learning Rate=0.100, Error=1.031
# Epoch=21, Learning Rate=0.100, Error=1.030
# Epoch=22, Learning Rate=0.100, Error=1.030
# Epoch=23, Learning Rate=0.100, Error=1.029
# Epoch=24, Learning Rate=0.100, Error=1.028
# Epoch=25, Learning Rate=0.100, Error=1.028
# Epoch=26, Learning Rate=0.100, Error=1.027
# Epoch=27, Learning Rate=0.100, Error=1.027
# Epoch=28, Learning Rate=0.100, Error=1.026
# Epoch=29, Learning Rate=0.100, Error=1.026
# Epoch=30, Learning Rate=0.100, Error=1.025
# Epoch=31, Learning Rate=0.100, Error=1.025
# Epoch=32, Learning Rate=0.100, Error=1.024
# Epoch=33, Learning Rate=0.100, Error=1.024
# Epoch=34, Learning Rate=0.100, Error=1.024
# Epoch=35, Learning Rate=0.100, Error=1.023
# Epoch=36, Learning Rate=0.100, Error=1.023
# Epoch=37, Learning Rate=0.100, Error=1.023
# Epoch=38, Learning Rate=0.100, Error=1.022
# Epoch=39, Learning Rate=0.100, Error=1.022
# Epoch=40, Learning Rate=0.100, Error=1.022
# Epoch=41, Learning Rate=0.100, Error=1.021
# Epoch=42, Learning Rate=0.100, Error=1.021
# Epoch=43, Learning Rate=0.100, Error=1.021
# Epoch=44, Learning Rate=0.100, Error=1.021
# Epoch=45, Learning Rate=0.100, Error=1.020
# Epoch=46, Learning Rate=0.100, Error=1.020
# Epoch=47, Learning Rate=0.100, Error=1.020
# Epoch=48, Learning Rate=0.100, Error=1.020
# Epoch=49, Learning Rate=0.100, Error=1.020
# Epoch=50, Learning Rate=0.100, Error=1.019
# Epoch=51, Learning Rate=0.100, Error=1.019
# Epoch=52, Learning Rate=0.100, Error=1.019
# Epoch=53, Learning Rate=0.100, Error=1.019
# Epoch=54, Learning Rate=0.100, Error=1.019
# Epoch=55, Learning Rate=0.100, Error=1.019
# Epoch=56, Learning Rate=0.100, Error=1.018
# Epoch=57, Learning Rate=0.100, Error=1.018
# Epoch=58, Learning Rate=0.100, Error=1.018
# Epoch=59, Learning Rate=0.100, Error=1.018
# Epoch=60, Learning Rate=0.100, Error=1.018
# Epoch=61, Learning Rate=0.100, Error=1.018
# Epoch=62, Learning Rate=0.100, Error=1.018
# Epoch=63, Learning Rate=0.100, Error=1.017
# Epoch=64, Learning Rate=0.100, Error=1.017
# Epoch=65, Learning Rate=0.100, Error=1.017
# Epoch=66, Learning Rate=0.100, Error=1.017
# Epoch=67, Learning Rate=0.100, Error=1.017
# Epoch=68, Learning Rate=0.100, Error=1.017
# Epoch=69, Learning Rate=0.100, Error=1.017
# Epoch=70, Learning Rate=0.100, Error=1.017
# Epoch=71, Learning Rate=0.100, Error=1.017
# Epoch=72, Learning Rate=0.100, Error=1.017
# Epoch=73, Learning Rate=0.100, Error=1.016
# Epoch=74, Learning Rate=0.100, Error=1.016
# Epoch=75, Learning Rate=0.100, Error=1.016
# Epoch=76, Learning Rate=0.100, Error=1.016
# Epoch=77, Learning Rate=0.100, Error=1.016
# Epoch=78, Learning Rate=0.100, Error=1.016
# Epoch=79, Learning Rate=0.100, Error=1.016
# Epoch=80, Learning Rate=0.100, Error=1.016
# Epoch=81, Learning Rate=0.100, Error=1.016
# Epoch=82, Learning Rate=0.100, Error=1.016
# Epoch=83, Learning Rate=0.100, Error=1.016
# Epoch=84, Learning Rate=0.100, Error=1.016
# Epoch=85, Learning Rate=0.100, Error=1.016
# Epoch=86, Learning Rate=0.100, Error=1.016
# Epoch=87, Learning Rate=0.100, Error=1.016
# Epoch=88, Learning Rate=0.100, Error=1.015
# Epoch=89, Learning Rate=0.100, Error=1.015
# Epoch=90, Learning Rate=0.100, Error=1.015
# Epoch=91, Learning Rate=0.100, Error=1.015
# Epoch=92, Learning Rate=0.100, Error=1.015
# Epoch=93, Learning Rate=0.100, Error=1.015
# Epoch=94, Learning Rate=0.100, Error=1.015
# Epoch=95, Learning Rate=0.100, Error=1.015
# Epoch=96, Learning Rate=0.100, Error=1.015
# Epoch=97, Learning Rate=0.100, Error=1.015
# Epoch=98, Learning Rate=0.100, Error=1.015
# Epoch=99, Learning Rate=0.100, Error=1.015
# Epoch=100, Learning Rate=0.100, Error=1.015
# Epoch=101, Learning Rate=0.100, Error=1.015
# Epoch=102, Learning Rate=0.100, Error=1.015
# Epoch=103, Learning Rate=0.100, Error=1.015
# Epoch=104, Learning Rate=0.100, Error=1.015
# Epoch=105, Learning Rate=0.100, Error=1.015
# Epoch=106, Learning Rate=0.100, Error=1.015
# Epoch=107, Learning Rate=0.100, Error=1.015
# Epoch=108, Learning Rate=0.100, Error=1.014
# Epoch=109, Learning Rate=0.100, Error=1.014
# Epoch=110, Learning Rate=0.100, Error=1.014
# Epoch=111, Learning Rate=0.100, Error=1.014
# Epoch=112, Learning Rate=0.100, Error=1.014
# Epoch=113, Learning Rate=0.100, Error=1.014
# Epoch=114, Learning Rate=0.100, Error=1.014
# Epoch=115, Learning Rate=0.100, Error=1.014
# Epoch=116, Learning Rate=0.100, Error=1.014
# Epoch=117, Learning Rate=0.100, Error=1.014
# Epoch=118, Learning Rate=0.100, Error=1.014
# Epoch=119, Learning Rate=0.100, Error=1.014
# Epoch=120, Learning Rate=0.100, Error=1.014
# Epoch=121, Learning Rate=0.100, Error=1.014
# Epoch=122, Learning Rate=0.100, Error=1.014
# Epoch=123, Learning Rate=0.100, Error=1.014
# Epoch=124, Learning Rate=0.100, Error=1.014
# Epoch=125, Learning Rate=0.100, Error=1.014
# Epoch=126, Learning Rate=0.100, Error=1.014
# Epoch=127, Learning Rate=0.100, Error=1.014
# Epoch=128, Learning Rate=0.100, Error=1.014
# Epoch=129, Learning Rate=0.100, Error=1.014
# Epoch=130, Learning Rate=0.100, Error=1.014
# Epoch=131, Learning Rate=0.100, Error=1.014
# Epoch=132, Learning Rate=0.100, Error=1.014
# Epoch=133, Learning Rate=0.100, Error=1.013
# Epoch=134, Learning Rate=0.100, Error=1.013
# Epoch=135, Learning Rate=0.100, Error=1.013
# Epoch=136, Learning Rate=0.100, Error=1.013
# Epoch=137, Learning Rate=0.100, Error=1.013
# Epoch=138, Learning Rate=0.100, Error=1.013
# Epoch=139, Learning Rate=0.100, Error=1.013
# Epoch=140, Learning Rate=0.100, Error=1.013
# Epoch=141, Learning Rate=0.100, Error=1.013
# Epoch=142, Learning Rate=0.100, Error=1.013
# Epoch=143, Learning Rate=0.100, Error=1.013
# Epoch=144, Learning Rate=0.100, Error=1.013
# Epoch=145, Learning Rate=0.100, Error=1.013
# Epoch=146, Learning Rate=0.100, Error=1.013
# Epoch=147, Learning Rate=0.100, Error=1.013
# Epoch=148, Learning Rate=0.100, Error=1.013
# Epoch=149, Learning Rate=0.100, Error=1.013
# Epoch=150, Learning Rate=0.100, Error=1.013
# Epoch=151, Learning Rate=0.100, Error=1.013
# Epoch=152, Learning Rate=0.100, Error=1.013
# Epoch=153, Learning Rate=0.100, Error=1.013
# Epoch=154, Learning Rate=0.100, Error=1.013
# Epoch=155, Learning Rate=0.100, Error=1.013
# Epoch=156, Learning Rate=0.100, Error=1.013
# Epoch=157, Learning Rate=0.100, Error=1.013
# Epoch=158, Learning Rate=0.100, Error=1.013
# Epoch=159, Learning Rate=0.100, Error=1.012
# Epoch=160, Learning Rate=0.100, Error=1.012
# Epoch=161, Learning Rate=0.100, Error=1.012
# Epoch=162, Learning Rate=0.100, Error=1.012
# Epoch=163, Learning Rate=0.100, Error=1.012
# Epoch=164, Learning Rate=0.100, Error=1.012
# Epoch=165, Learning Rate=0.100, Error=1.012
# Epoch=166, Learning Rate=0.100, Error=1.012
# Epoch=167, Learning Rate=0.100, Error=1.012
# Epoch=168, Learning Rate=0.100, Error=1.012
# Epoch=169, Learning Rate=0.100, Error=1.012
# Epoch=170, Learning Rate=0.100, Error=1.012
# Epoch=171, Learning Rate=0.100, Error=1.012
# Epoch=172, Learning Rate=0.100, Error=1.012
# Epoch=173, Learning Rate=0.100, Error=1.012
# Epoch=174, Learning Rate=0.100, Error=1.012
# Epoch=175, Learning Rate=0.100, Error=1.012
# Epoch=176, Learning Rate=0.100, Error=1.012
# Epoch=177, Learning Rate=0.100, Error=1.012
# Epoch=178, Learning Rate=0.100, Error=1.012
# Epoch=179, Learning Rate=0.100, Error=1.012
# Epoch=180, Learning Rate=0.100, Error=1.012
# Epoch=181, Learning Rate=0.100, Error=1.012
# Epoch=182, Learning Rate=0.100, Error=1.012
# Epoch=183, Learning Rate=0.100, Error=1.012
# Epoch=184, Learning Rate=0.100, Error=1.012
# Epoch=185, Learning Rate=0.100, Error=1.012
# Epoch=186, Learning Rate=0.100, Error=1.011
# Epoch=187, Learning Rate=0.100, Error=1.011
# Epoch=188, Learning Rate=0.100, Error=1.011
# Epoch=189, Learning Rate=0.100, Error=1.011
# Epoch=190, Learning Rate=0.100, Error=1.011
# Epoch=191, Learning Rate=0.100, Error=1.011
# Epoch=192, Learning Rate=0.100, Error=1.011
# Epoch=193, Learning Rate=0.100, Error=1.011
# Epoch=194, Learning Rate=0.100, Error=1.011
# Epoch=195, Learning Rate=0.100, Error=1.011
# Epoch=196, Learning Rate=0.100, Error=1.011
# Epoch=197, Learning Rate=0.100, Error=1.011
# Epoch=198, Learning Rate=0.100, Error=1.011
# Epoch=199, Learning Rate=0.100, Error=1.011
# Epoch=200, Learning Rate=0.100, Error=1.011
# Epoch=201, Learning Rate=0.100, Error=1.011
# Epoch=202, Learning Rate=0.100, Error=1.011
# Epoch=203, Learning Rate=0.100, Error=1.011
# Epoch=204, Learning Rate=0.100, Error=1.011
# Epoch=205, Learning Rate=0.100, Error=1.011
# Epoch=206, Learning Rate=0.100, Error=1.011
# Epoch=207, Learning Rate=0.100, Error=1.011
# Epoch=208, Learning Rate=0.100, Error=1.011
# Epoch=209, Learning Rate=0.100, Error=1.011
# Epoch=210, Learning Rate=0.100, Error=1.011
# Epoch=211, Learning Rate=0.100, Error=1.011
# Epoch=212, Learning Rate=0.100, Error=1.011
# Epoch=213, Learning Rate=0.100, Error=1.010
# Epoch=214, Learning Rate=0.100, Error=1.010
# Epoch=215, Learning Rate=0.100, Error=1.010
# Epoch=216, Learning Rate=0.100, Error=1.010
# Epoch=217, Learning Rate=0.100, Error=1.010
# Epoch=218, Learning Rate=0.100, Error=1.010
# Epoch=219, Learning Rate=0.100, Error=1.010
# Epoch=220, Learning Rate=0.100, Error=1.010
# Epoch=221, Learning Rate=0.100, Error=1.010
# Epoch=222, Learning Rate=0.100, Error=1.010
# Epoch=223, Learning Rate=0.100, Error=1.010
# Epoch=224, Learning Rate=0.100, Error=1.010
# Epoch=225, Learning Rate=0.100, Error=1.010
# Epoch=226, Learning Rate=0.100, Error=1.010
# Epoch=227, Learning Rate=0.100, Error=1.010
# Epoch=228, Learning Rate=0.100, Error=1.010
# Epoch=229, Learning Rate=0.100, Error=1.010
# Epoch=230, Learning Rate=0.100, Error=1.010
# Epoch=231, Learning Rate=0.100, Error=1.010
# Epoch=232, Learning Rate=0.100, Error=1.010
# Epoch=233, Learning Rate=0.100, Error=1.010
# Epoch=234, Learning Rate=0.100, Error=1.010
# Epoch=235, Learning Rate=0.100, Error=1.010
# Epoch=236, Learning Rate=0.100, Error=1.010
# Epoch=237, Learning Rate=0.100, Error=1.010
# Epoch=238, Learning Rate=0.100, Error=1.009
# Epoch=239, Learning Rate=0.100, Error=1.009
# Epoch=240, Learning Rate=0.100, Error=1.009
# Epoch=241, Learning Rate=0.100, Error=1.009
# Epoch=242, Learning Rate=0.100, Error=1.009
# Epoch=243, Learning Rate=0.100, Error=1.009
# Epoch=244, Learning Rate=0.100, Error=1.009
# Epoch=245, Learning Rate=0.100, Error=1.009
# Epoch=246, Learning Rate=0.100, Error=1.009
# Epoch=247, Learning Rate=0.100, Error=1.009
# Epoch=248, Learning Rate=0.100, Error=1.009
# Epoch=249, Learning Rate=0.100, Error=1.009
# Epoch=250, Learning Rate=0.100, Error=1.009
# Epoch=251, Learning Rate=0.100, Error=1.009
# Epoch=252, Learning Rate=0.100, Error=1.009
# Epoch=253, Learning Rate=0.100, Error=1.009
# Epoch=254, Learning Rate=0.100, Error=1.009
# Epoch=255, Learning Rate=0.100, Error=1.009
# Epoch=256, Learning Rate=0.100, Error=1.009
# Epoch=257, Learning Rate=0.100, Error=1.009
# Epoch=258, Learning Rate=0.100, Error=1.009
# Epoch=259, Learning Rate=0.100, Error=1.009
# Epoch=260, Learning Rate=0.100, Error=1.009
# Epoch=261, Learning Rate=0.100, Error=1.009
# Epoch=262, Learning Rate=0.100, Error=1.009
# Epoch=263, Learning Rate=0.100, Error=1.008
# Epoch=264, Learning Rate=0.100, Error=1.008
# Epoch=265, Learning Rate=0.100, Error=1.008
# Epoch=266, Learning Rate=0.100, Error=1.008
# Epoch=267, Learning Rate=0.100, Error=1.008
# Epoch=268, Learning Rate=0.100, Error=1.008
# Epoch=269, Learning Rate=0.100, Error=1.008
# Epoch=270, Learning Rate=0.100, Error=1.008
# Epoch=271, Learning Rate=0.100, Error=1.008
# Epoch=272, Learning Rate=0.100, Error=1.008
# Epoch=273, Learning Rate=0.100, Error=1.008
# Epoch=274, Learning Rate=0.100, Error=1.008
# Epoch=275, Learning Rate=0.100, Error=1.008
# Epoch=276, Learning Rate=0.100, Error=1.008
# Epoch=277, Learning Rate=0.100, Error=1.008
# Epoch=278, Learning Rate=0.100, Error=1.008
# Epoch=279, Learning Rate=0.100, Error=1.008
# Epoch=280, Learning Rate=0.100, Error=1.008
# Epoch=281, Learning Rate=0.100, Error=1.008
# Epoch=282, Learning Rate=0.100, Error=1.008
# Epoch=283, Learning Rate=0.100, Error=1.008
# Epoch=284, Learning Rate=0.100, Error=1.008
# Epoch=285, Learning Rate=0.100, Error=1.008
# Epoch=286, Learning Rate=0.100, Error=1.008
# Epoch=287, Learning Rate=0.100, Error=1.007
# Epoch=288, Learning Rate=0.100, Error=1.007
# Epoch=289, Learning Rate=0.100, Error=1.007
# Epoch=290, Learning Rate=0.100, Error=1.007
# Epoch=291, Learning Rate=0.100, Error=1.007
# Epoch=292, Learning Rate=0.100, Error=1.007
# Epoch=293, Learning Rate=0.100, Error=1.007
# Epoch=294, Learning Rate=0.100, Error=1.007
# Epoch=295, Learning Rate=0.100, Error=1.007
# Epoch=296, Learning Rate=0.100, Error=1.007
# Epoch=297, Learning Rate=0.100, Error=1.007
# Epoch=298, Learning Rate=0.100, Error=1.007
# Epoch=299, Learning Rate=0.100, Error=1.007
# Epoch=300, Learning Rate=0.100, Error=1.007
# Epoch=301, Learning Rate=0.100, Error=1.007
# Epoch=302, Learning Rate=0.100, Error=1.007
# Epoch=303, Learning Rate=0.100, Error=1.007
# Epoch=304, Learning Rate=0.100, Error=1.007
# Epoch=305, Learning Rate=0.100, Error=1.007
# Epoch=306, Learning Rate=0.100, Error=1.007
# Epoch=307, Learning Rate=0.100, Error=1.007
# Epoch=308, Learning Rate=0.100, Error=1.007
# Epoch=309, Learning Rate=0.100, Error=1.007
# Epoch=310, Learning Rate=0.100, Error=1.006
# Epoch=311, Learning Rate=0.100, Error=1.006
# Epoch=312, Learning Rate=0.100, Error=1.006
# Epoch=313, Learning Rate=0.100, Error=1.006
# Epoch=314, Learning Rate=0.100, Error=1.006
# Epoch=315, Learning Rate=0.100, Error=1.006
# Epoch=316, Learning Rate=0.100, Error=1.006
# Epoch=317, Learning Rate=0.100, Error=1.006
# Epoch=318, Learning Rate=0.100, Error=1.006
# Epoch=319, Learning Rate=0.100, Error=1.006
# Epoch=320, Learning Rate=0.100, Error=1.006
# Epoch=321, Learning Rate=0.100, Error=1.006
# Epoch=322, Learning Rate=0.100, Error=1.006
# Epoch=323, Learning Rate=0.100, Error=1.006
# Epoch=324, Learning Rate=0.100, Error=1.006
# Epoch=325, Learning Rate=0.100, Error=1.006
# Epoch=326, Learning Rate=0.100, Error=1.006
# Epoch=327, Learning Rate=0.100, Error=1.006
# Epoch=328, Learning Rate=0.100, Error=1.006
# Epoch=329, Learning Rate=0.100, Error=1.006
# Epoch=330, Learning Rate=0.100, Error=1.006
# Epoch=331, Learning Rate=0.100, Error=1.006
# Epoch=332, Learning Rate=0.100, Error=1.005
# Epoch=333, Learning Rate=0.100, Error=1.005
# Epoch=334, Learning Rate=0.100, Error=1.005
# Epoch=335, Learning Rate=0.100, Error=1.005
# Epoch=336, Learning Rate=0.100, Error=1.005
# Epoch=337, Learning Rate=0.100, Error=1.005
# Epoch=338, Learning Rate=0.100, Error=1.005
# Epoch=339, Learning Rate=0.100, Error=1.005
# Epoch=340, Learning Rate=0.100, Error=1.005
# Epoch=341, Learning Rate=0.100, Error=1.005
# Epoch=342, Learning Rate=0.100, Error=1.005
# Epoch=343, Learning Rate=0.100, Error=1.005
# Epoch=344, Learning Rate=0.100, Error=1.005
# Epoch=345, Learning Rate=0.100, Error=1.005
# Epoch=346, Learning Rate=0.100, Error=1.005
# Epoch=347, Learning Rate=0.100, Error=1.005
# Epoch=348, Learning Rate=0.100, Error=1.005
# Epoch=349, Learning Rate=0.100, Error=1.005
# Epoch=350, Learning Rate=0.100, Error=1.005
# Epoch=351, Learning Rate=0.100, Error=1.005
# Epoch=352, Learning Rate=0.100, Error=1.005
# Epoch=353, Learning Rate=0.100, Error=1.004
# Epoch=354, Learning Rate=0.100, Error=1.004
# Epoch=355, Learning Rate=0.100, Error=1.004
# Epoch=356, Learning Rate=0.100, Error=1.004
# Epoch=357, Learning Rate=0.100, Error=1.004
# Epoch=358, Learning Rate=0.100, Error=1.004
# Epoch=359, Learning Rate=0.100, Error=1.004
# Epoch=360, Learning Rate=0.100, Error=1.004
# Epoch=361, Learning Rate=0.100, Error=1.004
# Epoch=362, Learning Rate=0.100, Error=1.004
# Epoch=363, Learning Rate=0.100, Error=1.004
# Epoch=364, Learning Rate=0.100, Error=1.004
# Epoch=365, Learning Rate=0.100, Error=1.004
# Epoch=366, Learning Rate=0.100, Error=1.004
# Epoch=367, Learning Rate=0.100, Error=1.004
# Epoch=368, Learning Rate=0.100, Error=1.004
# Epoch=369, Learning Rate=0.100, Error=1.004
# Epoch=370, Learning Rate=0.100, Error=1.004
# Epoch=371, Learning Rate=0.100, Error=1.004
# Epoch=372, Learning Rate=0.100, Error=1.004
# Epoch=373, Learning Rate=0.100, Error=1.003
# Epoch=374, Learning Rate=0.100, Error=1.003
# Epoch=375, Learning Rate=0.100, Error=1.003
# Epoch=376, Learning Rate=0.100, Error=1.003
# Epoch=377, Learning Rate=0.100, Error=1.003
# Epoch=378, Learning Rate=0.100, Error=1.003
# Epoch=379, Learning Rate=0.100, Error=1.003
# Epoch=380, Learning Rate=0.100, Error=1.003
# Epoch=381, Learning Rate=0.100, Error=1.003
# Epoch=382, Learning Rate=0.100, Error=1.003
# Epoch=383, Learning Rate=0.100, Error=1.003
# Epoch=384, Learning Rate=0.100, Error=1.003
# Epoch=385, Learning Rate=0.100, Error=1.003
# Epoch=386, Learning Rate=0.100, Error=1.003
# Epoch=387, Learning Rate=0.100, Error=1.003
# Epoch=388, Learning Rate=0.100, Error=1.003
# Epoch=389, Learning Rate=0.100, Error=1.003
# Epoch=390, Learning Rate=0.100, Error=1.003
# Epoch=391, Learning Rate=0.100, Error=1.003
# Epoch=392, Learning Rate=0.100, Error=1.003
# Epoch=393, Learning Rate=0.100, Error=1.002
# Epoch=394, Learning Rate=0.100, Error=1.002
# Epoch=395, Learning Rate=0.100, Error=1.002
# Epoch=396, Learning Rate=0.100, Error=1.002
# Epoch=397, Learning Rate=0.100, Error=1.002
# Epoch=398, Learning Rate=0.100, Error=1.002
# Epoch=399, Learning Rate=0.100, Error=1.002
# Epoch=400, Learning Rate=0.100, Error=1.002
# Epoch=401, Learning Rate=0.100, Error=1.002
# Epoch=402, Learning Rate=0.100, Error=1.002
# Epoch=403, Learning Rate=0.100, Error=1.002
# Epoch=404, Learning Rate=0.100, Error=1.002
# Epoch=405, Learning Rate=0.100, Error=1.002
# Epoch=406, Learning Rate=0.100, Error=1.002
# Epoch=407, Learning Rate=0.100, Error=1.002
# Epoch=408, Learning Rate=0.100, Error=1.002
# Epoch=409, Learning Rate=0.100, Error=1.002
# Epoch=410, Learning Rate=0.100, Error=1.002
# Epoch=411, Learning Rate=0.100, Error=1.001
# Epoch=412, Learning Rate=0.100, Error=1.001
# Epoch=413, Learning Rate=0.100, Error=1.001
# Epoch=414, Learning Rate=0.100, Error=1.001
# Epoch=415, Learning Rate=0.100, Error=1.001
# Epoch=416, Learning Rate=0.100, Error=1.001
# Epoch=417, Learning Rate=0.100, Error=1.001
# Epoch=418, Learning Rate=0.100, Error=1.001
# Epoch=419, Learning Rate=0.100, Error=1.001
# Epoch=420, Learning Rate=0.100, Error=1.001
# Epoch=421, Learning Rate=0.100, Error=1.001
# Epoch=422, Learning Rate=0.100, Error=1.001
# Epoch=423, Learning Rate=0.100, Error=1.001
# Epoch=424, Learning Rate=0.100, Error=1.001
# Epoch=425, Learning Rate=0.100, Error=1.001
# Epoch=426, Learning Rate=0.100, Error=1.001
# Epoch=427, Learning Rate=0.100, Error=1.001
# Epoch=428, Learning Rate=0.100, Error=1.001
# Epoch=429, Learning Rate=0.100, Error=1.000
# Epoch=430, Learning Rate=0.100, Error=1.000
# Epoch=431, Learning Rate=0.100, Error=1.000
# Epoch=432, Learning Rate=0.100, Error=1.000
# Epoch=433, Learning Rate=0.100, Error=1.000
# Epoch=434, Learning Rate=0.100, Error=1.000
# Epoch=435, Learning Rate=0.100, Error=1.000
# Epoch=436, Learning Rate=0.100, Error=1.000
# Epoch=437, Learning Rate=0.100, Error=1.000
# Epoch=438, Learning Rate=0.100, Error=1.000
# Epoch=439, Learning Rate=0.100, Error=1.000
# Epoch=440, Learning Rate=0.100, Error=1.000
# Epoch=441, Learning Rate=0.100, Error=1.000
# Epoch=442, Learning Rate=0.100, Error=1.000
# Epoch=443, Learning Rate=0.100, Error=1.000
# Epoch=444, Learning Rate=0.100, Error=1.000
# Epoch=445, Learning Rate=0.100, Error=1.000
# Epoch=446, Learning Rate=0.100, Error=0.999
# Epoch=447, Learning Rate=0.100, Error=0.999
# Epoch=448, Learning Rate=0.100, Error=0.999
# Epoch=449, Learning Rate=0.100, Error=0.999
# Epoch=450, Learning Rate=0.100, Error=0.999
# Epoch=451, Learning Rate=0.100, Error=0.999
# Epoch=452, Learning Rate=0.100, Error=0.999
# Epoch=453, Learning Rate=0.100, Error=0.999
# Epoch=454, Learning Rate=0.100, Error=0.999
# Epoch=455, Learning Rate=0.100, Error=0.999
# Epoch=456, Learning Rate=0.100, Error=0.999
# Epoch=457, Learning Rate=0.100, Error=0.999
# Epoch=458, Learning Rate=0.100, Error=0.999
# Epoch=459, Learning Rate=0.100, Error=0.999
# Epoch=460, Learning Rate=0.100, Error=0.999
# Epoch=461, Learning Rate=0.100, Error=0.999
# Epoch=462, Learning Rate=0.100, Error=0.998
# Epoch=463, Learning Rate=0.100, Error=0.998
# Epoch=464, Learning Rate=0.100, Error=0.998
# Epoch=465, Learning Rate=0.100, Error=0.998
# Epoch=466, Learning Rate=0.100, Error=0.998
# Epoch=467, Learning Rate=0.100, Error=0.998
# Epoch=468, Learning Rate=0.100, Error=0.998
# Epoch=469, Learning Rate=0.100, Error=0.998
# Epoch=470, Learning Rate=0.100, Error=0.998
# Epoch=471, Learning Rate=0.100, Error=0.998
# Epoch=472, Learning Rate=0.100, Error=0.998
# Epoch=473, Learning Rate=0.100, Error=0.998
# Epoch=474, Learning Rate=0.100, Error=0.998
# Epoch=475, Learning Rate=0.100, Error=0.998
# Epoch=476, Learning Rate=0.100, Error=0.998
# Epoch=477, Learning Rate=0.100, Error=0.997
# Epoch=478, Learning Rate=0.100, Error=0.997
# Epoch=479, Learning Rate=0.100, Error=0.997
# Epoch=480, Learning Rate=0.100, Error=0.997
# Epoch=481, Learning Rate=0.100, Error=0.997
# Epoch=482, Learning Rate=0.100, Error=0.997
# Epoch=483, Learning Rate=0.100, Error=0.997
# Epoch=484, Learning Rate=0.100, Error=0.997
# Epoch=485, Learning Rate=0.100, Error=0.997
# Epoch=486, Learning Rate=0.100, Error=0.997
# Epoch=487, Learning Rate=0.100, Error=0.997
# Epoch=488, Learning Rate=0.100, Error=0.997
# Epoch=489, Learning Rate=0.100, Error=0.997
# Epoch=490, Learning Rate=0.100, Error=0.997
# Epoch=491, Learning Rate=0.100, Error=0.997
# Epoch=492, Learning Rate=0.100, Error=0.996
# Epoch=493, Learning Rate=0.100, Error=0.996
# Epoch=494, Learning Rate=0.100, Error=0.996
# Epoch=495, Learning Rate=0.100, Error=0.996
# Epoch=496, Learning Rate=0.100, Error=0.996
# Epoch=497, Learning Rate=0.100, Error=0.996
# Epoch=498, Learning Rate=0.100, Error=0.996
# Epoch=499, Learning Rate=0.100, Error=0.996
# Epoch=500, Learning Rate=0.100, Error=0.996
# Epoch=501, Learning Rate=0.100, Error=0.996
# Epoch=502, Learning Rate=0.100, Error=0.996
# Epoch=503, Learning Rate=0.100, Error=0.996
# Epoch=504, Learning Rate=0.100, Error=0.996
# Epoch=505, Learning Rate=0.100, Error=0.996
# Epoch=506, Learning Rate=0.100, Error=0.995
# Epoch=507, Learning Rate=0.100, Error=0.995
# Epoch=508, Learning Rate=0.100, Error=0.995
# Epoch=509, Learning Rate=0.100, Error=0.995
# Epoch=510, Learning Rate=0.100, Error=0.995
# Epoch=511, Learning Rate=0.100, Error=0.995
# Epoch=512, Learning Rate=0.100, Error=0.995
# Epoch=513, Learning Rate=0.100, Error=0.995
# Epoch=514, Learning Rate=0.100, Error=0.995
# Epoch=515, Learning Rate=0.100, Error=0.995
# Epoch=516, Learning Rate=0.100, Error=0.995
# Epoch=517, Learning Rate=0.100, Error=0.995
# Epoch=518, Learning Rate=0.100, Error=0.995
# Epoch=519, Learning Rate=0.100, Error=0.995
# Epoch=520, Learning Rate=0.100, Error=0.994
# Epoch=521, Learning Rate=0.100, Error=0.994
# Epoch=522, Learning Rate=0.100, Error=0.994
# Epoch=523, Learning Rate=0.100, Error=0.994
# Epoch=524, Learning Rate=0.100, Error=0.994
# Epoch=525, Learning Rate=0.100, Error=0.994
# Epoch=526, Learning Rate=0.100, Error=0.994
# Epoch=527, Learning Rate=0.100, Error=0.994
# Epoch=528, Learning Rate=0.100, Error=0.994
# Epoch=529, Learning Rate=0.100, Error=0.994
# Epoch=530, Learning Rate=0.100, Error=0.994
# Epoch=531, Learning Rate=0.100, Error=0.994
# Epoch=532, Learning Rate=0.100, Error=0.994
# Epoch=533, Learning Rate=0.100, Error=0.993
# Epoch=534, Learning Rate=0.100, Error=0.993
# Epoch=535, Learning Rate=0.100, Error=0.993
# Epoch=536, Learning Rate=0.100, Error=0.993
# Epoch=537, Learning Rate=0.100, Error=0.993
# Epoch=538, Learning Rate=0.100, Error=0.993
# Epoch=539, Learning Rate=0.100, Error=0.993
# Epoch=540, Learning Rate=0.100, Error=0.993
# Epoch=541, Learning Rate=0.100, Error=0.993
# Epoch=542, Learning Rate=0.100, Error=0.993
# Epoch=543, Learning Rate=0.100, Error=0.993
# Epoch=544, Learning Rate=0.100, Error=0.993
# Epoch=545, Learning Rate=0.100, Error=0.993
# Epoch=546, Learning Rate=0.100, Error=0.992
# Epoch=547, Learning Rate=0.100, Error=0.992
# Epoch=548, Learning Rate=0.100, Error=0.992
# Epoch=549, Learning Rate=0.100, Error=0.992
# Epoch=550, Learning Rate=0.100, Error=0.992
# Epoch=551, Learning Rate=0.100, Error=0.992
# Epoch=552, Learning Rate=0.100, Error=0.992
# Epoch=553, Learning Rate=0.100, Error=0.992
# Epoch=554, Learning Rate=0.100, Error=0.992
# Epoch=555, Learning Rate=0.100, Error=0.992
# Epoch=556, Learning Rate=0.100, Error=0.992
# Epoch=557, Learning Rate=0.100, Error=0.992
# Epoch=558, Learning Rate=0.100, Error=0.991
# Epoch=559, Learning Rate=0.100, Error=0.991
# Epoch=560, Learning Rate=0.100, Error=0.991
# Epoch=561, Learning Rate=0.100, Error=0.991
# Epoch=562, Learning Rate=0.100, Error=0.991
# Epoch=563, Learning Rate=0.100, Error=0.991
# Epoch=564, Learning Rate=0.100, Error=0.991
# Epoch=565, Learning Rate=0.100, Error=0.991
# Epoch=566, Learning Rate=0.100, Error=0.991
# Epoch=567, Learning Rate=0.100, Error=0.991
# Epoch=568, Learning Rate=0.100, Error=0.991
# Epoch=569, Learning Rate=0.100, Error=0.991
# Epoch=570, Learning Rate=0.100, Error=0.990
# Epoch=571, Learning Rate=0.100, Error=0.990
# Epoch=572, Learning Rate=0.100, Error=0.990
# Epoch=573, Learning Rate=0.100, Error=0.990
# Epoch=574, Learning Rate=0.100, Error=0.990
# Epoch=575, Learning Rate=0.100, Error=0.990
# Epoch=576, Learning Rate=0.100, Error=0.990
# Epoch=577, Learning Rate=0.100, Error=0.990
# Epoch=578, Learning Rate=0.100, Error=0.990
# Epoch=579, Learning Rate=0.100, Error=0.990
# Epoch=580, Learning Rate=0.100, Error=0.990
# Epoch=581, Learning Rate=0.100, Error=0.990
# Epoch=582, Learning Rate=0.100, Error=0.989
# Epoch=583, Learning Rate=0.100, Error=0.989
# Epoch=584, Learning Rate=0.100, Error=0.989
# Epoch=585, Learning Rate=0.100, Error=0.989
# Epoch=586, Learning Rate=0.100, Error=0.989
# Epoch=587, Learning Rate=0.100, Error=0.989
# Epoch=588, Learning Rate=0.100, Error=0.989
# Epoch=589, Learning Rate=0.100, Error=0.989
# Epoch=590, Learning Rate=0.100, Error=0.989
# Epoch=591, Learning Rate=0.100, Error=0.989
# Epoch=592, Learning Rate=0.100, Error=0.989
# Epoch=593, Learning Rate=0.100, Error=0.988
# Epoch=594, Learning Rate=0.100, Error=0.988
# Epoch=595, Learning Rate=0.100, Error=0.988
# Epoch=596, Learning Rate=0.100, Error=0.988
# Epoch=597, Learning Rate=0.100, Error=0.988
# Epoch=598, Learning Rate=0.100, Error=0.988
# Epoch=599, Learning Rate=0.100, Error=0.988
# Epoch=600, Learning Rate=0.100, Error=0.988
# Epoch=601, Learning Rate=0.100, Error=0.988
# Epoch=602, Learning Rate=0.100, Error=0.988
# Epoch=603, Learning Rate=0.100, Error=0.987
# Epoch=604, Learning Rate=0.100, Error=0.987
# Epoch=605, Learning Rate=0.100, Error=0.987
# Epoch=606, Learning Rate=0.100, Error=0.987
# Epoch=607, Learning Rate=0.100, Error=0.987
# Epoch=608, Learning Rate=0.100, Error=0.987
# Epoch=609, Learning Rate=0.100, Error=0.987
# Epoch=610, Learning Rate=0.100, Error=0.987
# Epoch=611, Learning Rate=0.100, Error=0.987
# Epoch=612, Learning Rate=0.100, Error=0.987
# Epoch=613, Learning Rate=0.100, Error=0.987
# Epoch=614, Learning Rate=0.100, Error=0.986
# Epoch=615, Learning Rate=0.100, Error=0.986
# Epoch=616, Learning Rate=0.100, Error=0.986
# Epoch=617, Learning Rate=0.100, Error=0.986
# Epoch=618, Learning Rate=0.100, Error=0.986
# Epoch=619, Learning Rate=0.100, Error=0.986
# Epoch=620, Learning Rate=0.100, Error=0.986
# Epoch=621, Learning Rate=0.100, Error=0.986
# Epoch=622, Learning Rate=0.100, Error=0.986
# Epoch=623, Learning Rate=0.100, Error=0.986
# Epoch=624, Learning Rate=0.100, Error=0.985
# Epoch=625, Learning Rate=0.100, Error=0.985
# Epoch=626, Learning Rate=0.100, Error=0.985
# Epoch=627, Learning Rate=0.100, Error=0.985
# Epoch=628, Learning Rate=0.100, Error=0.985
# Epoch=629, Learning Rate=0.100, Error=0.985
# Epoch=630, Learning Rate=0.100, Error=0.985
# Epoch=631, Learning Rate=0.100, Error=0.985
# Epoch=632, Learning Rate=0.100, Error=0.985
# Epoch=633, Learning Rate=0.100, Error=0.985
# Epoch=634, Learning Rate=0.100, Error=0.984
# Epoch=635, Learning Rate=0.100, Error=0.984
# Epoch=636, Learning Rate=0.100, Error=0.984
# Epoch=637, Learning Rate=0.100, Error=0.984
# Epoch=638, Learning Rate=0.100, Error=0.984
# Epoch=639, Learning Rate=0.100, Error=0.984
# Epoch=640, Learning Rate=0.100, Error=0.984
# Epoch=641, Learning Rate=0.100, Error=0.984
# Epoch=642, Learning Rate=0.100, Error=0.984
# Epoch=643, Learning Rate=0.100, Error=0.983
# Epoch=644, Learning Rate=0.100, Error=0.983
# Epoch=645, Learning Rate=0.100, Error=0.983
# Epoch=646, Learning Rate=0.100, Error=0.983
# Epoch=647, Learning Rate=0.100, Error=0.983
# Epoch=648, Learning Rate=0.100, Error=0.983
# Epoch=649, Learning Rate=0.100, Error=0.983
# Epoch=650, Learning Rate=0.100, Error=0.983
# Epoch=651, Learning Rate=0.100, Error=0.983
# Epoch=652, Learning Rate=0.100, Error=0.982
# Epoch=653, Learning Rate=0.100, Error=0.982
# Epoch=654, Learning Rate=0.100, Error=0.982
# Epoch=655, Learning Rate=0.100, Error=0.982
# Epoch=656, Learning Rate=0.100, Error=0.982
# Epoch=657, Learning Rate=0.100, Error=0.982
# Epoch=658, Learning Rate=0.100, Error=0.982
# Epoch=659, Learning Rate=0.100, Error=0.982
# Epoch=660, Learning Rate=0.100, Error=0.982
# Epoch=661, Learning Rate=0.100, Error=0.981
# Epoch=662, Learning Rate=0.100, Error=0.981
# Epoch=663, Learning Rate=0.100, Error=0.981
# Epoch=664, Learning Rate=0.100, Error=0.981
# Epoch=665, Learning Rate=0.100, Error=0.981
# Epoch=666, Learning Rate=0.100, Error=0.981
# Epoch=667, Learning Rate=0.100, Error=0.981
# Epoch=668, Learning Rate=0.100, Error=0.981
# Epoch=669, Learning Rate=0.100, Error=0.981
# Epoch=670, Learning Rate=0.100, Error=0.980
# Epoch=671, Learning Rate=0.100, Error=0.980
# Epoch=672, Learning Rate=0.100, Error=0.980
# Epoch=673, Learning Rate=0.100, Error=0.980
# Epoch=674, Learning Rate=0.100, Error=0.980
# Epoch=675, Learning Rate=0.100, Error=0.980
# Epoch=676, Learning Rate=0.100, Error=0.980
# Epoch=677, Learning Rate=0.100, Error=0.980
# Epoch=678, Learning Rate=0.100, Error=0.980
# Epoch=679, Learning Rate=0.100, Error=0.979
# Epoch=680, Learning Rate=0.100, Error=0.979
# Epoch=681, Learning Rate=0.100, Error=0.979
# Epoch=682, Learning Rate=0.100, Error=0.979
# Epoch=683, Learning Rate=0.100, Error=0.979
# Epoch=684, Learning Rate=0.100, Error=0.979
# Epoch=685, Learning Rate=0.100, Error=0.979
# Epoch=686, Learning Rate=0.100, Error=0.979
# Epoch=687, Learning Rate=0.100, Error=0.978
# Epoch=688, Learning Rate=0.100, Error=0.978
# Epoch=689, Learning Rate=0.100, Error=0.978
# Epoch=690, Learning Rate=0.100, Error=0.978
# Epoch=691, Learning Rate=0.100, Error=0.978
# Epoch=692, Learning Rate=0.100, Error=0.978
# Epoch=693, Learning Rate=0.100, Error=0.978
# Epoch=694, Learning Rate=0.100, Error=0.978
# Epoch=695, Learning Rate=0.100, Error=0.977
# Epoch=696, Learning Rate=0.100, Error=0.977
# Epoch=697, Learning Rate=0.100, Error=0.977
# Epoch=698, Learning Rate=0.100, Error=0.977
# Epoch=699, Learning Rate=0.100, Error=0.977
# Epoch=700, Learning Rate=0.100, Error=0.977
# Epoch=701, Learning Rate=0.100, Error=0.977
# Epoch=702, Learning Rate=0.100, Error=0.977
# Epoch=703, Learning Rate=0.100, Error=0.976
# Epoch=704, Learning Rate=0.100, Error=0.976
# Epoch=705, Learning Rate=0.100, Error=0.976
# Epoch=706, Learning Rate=0.100, Error=0.976
# Epoch=707, Learning Rate=0.100, Error=0.976
# Epoch=708, Learning Rate=0.100, Error=0.976
# Epoch=709, Learning Rate=0.100, Error=0.976
# Epoch=710, Learning Rate=0.100, Error=0.976
# Epoch=711, Learning Rate=0.100, Error=0.975
# Epoch=712, Learning Rate=0.100, Error=0.975
# Epoch=713, Learning Rate=0.100, Error=0.975
# Epoch=714, Learning Rate=0.100, Error=0.975
# Epoch=715, Learning Rate=0.100, Error=0.975
# Epoch=716, Learning Rate=0.100, Error=0.975
# Epoch=717, Learning Rate=0.100, Error=0.975
# Epoch=718, Learning Rate=0.100, Error=0.974
# Epoch=719, Learning Rate=0.100, Error=0.974
# Epoch=720, Learning Rate=0.100, Error=0.974
# Epoch=721, Learning Rate=0.100, Error=0.974
# Epoch=722, Learning Rate=0.100, Error=0.974
# Epoch=723, Learning Rate=0.100, Error=0.974
# Epoch=724, Learning Rate=0.100, Error=0.974
# Epoch=725, Learning Rate=0.100, Error=0.974
# Epoch=726, Learning Rate=0.100, Error=0.973
# Epoch=727, Learning Rate=0.100, Error=0.973
# Epoch=728, Learning Rate=0.100, Error=0.973
# Epoch=729, Learning Rate=0.100, Error=0.973
# Epoch=730, Learning Rate=0.100, Error=0.973
# Epoch=731, Learning Rate=0.100, Error=0.973
# Epoch=732, Learning Rate=0.100, Error=0.973
# Epoch=733, Learning Rate=0.100, Error=0.972
# Epoch=734, Learning Rate=0.100, Error=0.972
# Epoch=735, Learning Rate=0.100, Error=0.972
# Epoch=736, Learning Rate=0.100, Error=0.972
# Epoch=737, Learning Rate=0.100, Error=0.972
# Epoch=738, Learning Rate=0.100, Error=0.972
# Epoch=739, Learning Rate=0.100, Error=0.972
# Epoch=740, Learning Rate=0.100, Error=0.971
# Epoch=741, Learning Rate=0.100, Error=0.971
# Epoch=742, Learning Rate=0.100, Error=0.971
# Epoch=743, Learning Rate=0.100, Error=0.971
# Epoch=744, Learning Rate=0.100, Error=0.971
# Epoch=745, Learning Rate=0.100, Error=0.971
# Epoch=746, Learning Rate=0.100, Error=0.971
# Epoch=747, Learning Rate=0.100, Error=0.970
# Epoch=748, Learning Rate=0.100, Error=0.970
# Epoch=749, Learning Rate=0.100, Error=0.970
# Epoch=750, Learning Rate=0.100, Error=0.970
# Epoch=751, Learning Rate=0.100, Error=0.970
# Epoch=752, Learning Rate=0.100, Error=0.970
# Epoch=753, Learning Rate=0.100, Error=0.970
# Epoch=754, Learning Rate=0.100, Error=0.969
# Epoch=755, Learning Rate=0.100, Error=0.969
# Epoch=756, Learning Rate=0.100, Error=0.969
# Epoch=757, Learning Rate=0.100, Error=0.969
# Epoch=758, Learning Rate=0.100, Error=0.969
# Epoch=759, Learning Rate=0.100, Error=0.969
# Epoch=760, Learning Rate=0.100, Error=0.968
# Epoch=761, Learning Rate=0.100, Error=0.968
# Epoch=762, Learning Rate=0.100, Error=0.968
# Epoch=763, Learning Rate=0.100, Error=0.968
# Epoch=764, Learning Rate=0.100, Error=0.968
# Epoch=765, Learning Rate=0.100, Error=0.968
# Epoch=766, Learning Rate=0.100, Error=0.968
# Epoch=767, Learning Rate=0.100, Error=0.967
# Epoch=768, Learning Rate=0.100, Error=0.967
# Epoch=769, Learning Rate=0.100, Error=0.967
# Epoch=770, Learning Rate=0.100, Error=0.967
# Epoch=771, Learning Rate=0.100, Error=0.967
# Epoch=772, Learning Rate=0.100, Error=0.967
# Epoch=773, Learning Rate=0.100, Error=0.966
# Epoch=774, Learning Rate=0.100, Error=0.966
# Epoch=775, Learning Rate=0.100, Error=0.966
# Epoch=776, Learning Rate=0.100, Error=0.966
# Epoch=777, Learning Rate=0.100, Error=0.966
# Epoch=778, Learning Rate=0.100, Error=0.966
# Epoch=779, Learning Rate=0.100, Error=0.965
# Epoch=780, Learning Rate=0.100, Error=0.965
# Epoch=781, Learning Rate=0.100, Error=0.965
# Epoch=782, Learning Rate=0.100, Error=0.965
# Epoch=783, Learning Rate=0.100, Error=0.965
# Epoch=784, Learning Rate=0.100, Error=0.965
# Epoch=785, Learning Rate=0.100, Error=0.965
# Epoch=786, Learning Rate=0.100, Error=0.964
# Epoch=787, Learning Rate=0.100, Error=0.964
# Epoch=788, Learning Rate=0.100, Error=0.964
# Epoch=789, Learning Rate=0.100, Error=0.964
# Epoch=790, Learning Rate=0.100, Error=0.964
# Epoch=791, Learning Rate=0.100, Error=0.964
# Epoch=792, Learning Rate=0.100, Error=0.963
# Epoch=793, Learning Rate=0.100, Error=0.963
# Epoch=794, Learning Rate=0.100, Error=0.963
# Epoch=795, Learning Rate=0.100, Error=0.963
# Epoch=796, Learning Rate=0.100, Error=0.963
# Epoch=797, Learning Rate=0.100, Error=0.962
# Epoch=798, Learning Rate=0.100, Error=0.962
# Epoch=799, Learning Rate=0.100, Error=0.962
# Epoch=800, Learning Rate=0.100, Error=0.962
# Epoch=801, Learning Rate=0.100, Error=0.962
# Epoch=802, Learning Rate=0.100, Error=0.962
# Epoch=803, Learning Rate=0.100, Error=0.961
# Epoch=804, Learning Rate=0.100, Error=0.961
# Epoch=805, Learning Rate=0.100, Error=0.961
# Epoch=806, Learning Rate=0.100, Error=0.961
# Epoch=807, Learning Rate=0.100, Error=0.961
# Epoch=808, Learning Rate=0.100, Error=0.961
# Epoch=809, Learning Rate=0.100, Error=0.960
# Epoch=810, Learning Rate=0.100, Error=0.960
# Epoch=811, Learning Rate=0.100, Error=0.960
# Epoch=812, Learning Rate=0.100, Error=0.960
# Epoch=813, Learning Rate=0.100, Error=0.960
# Epoch=814, Learning Rate=0.100, Error=0.960
# Epoch=815, Learning Rate=0.100, Error=0.959
# Epoch=816, Learning Rate=0.100, Error=0.959
# Epoch=817, Learning Rate=0.100, Error=0.959
# Epoch=818, Learning Rate=0.100, Error=0.959
# Epoch=819, Learning Rate=0.100, Error=0.959
# Epoch=820, Learning Rate=0.100, Error=0.958
# Epoch=821, Learning Rate=0.100, Error=0.958
# Epoch=822, Learning Rate=0.100, Error=0.958
# Epoch=823, Learning Rate=0.100, Error=0.958
# Epoch=824, Learning Rate=0.100, Error=0.958
# Epoch=825, Learning Rate=0.100, Error=0.958
# Epoch=826, Learning Rate=0.100, Error=0.957
# Epoch=827, Learning Rate=0.100, Error=0.957
# Epoch=828, Learning Rate=0.100, Error=0.957
# Epoch=829, Learning Rate=0.100, Error=0.957
# Epoch=830, Learning Rate=0.100, Error=0.957
# Epoch=831, Learning Rate=0.100, Error=0.956
# Epoch=832, Learning Rate=0.100, Error=0.956
# Epoch=833, Learning Rate=0.100, Error=0.956
# Epoch=834, Learning Rate=0.100, Error=0.956
# Epoch=835, Learning Rate=0.100, Error=0.956
# Epoch=836, Learning Rate=0.100, Error=0.955
# Epoch=837, Learning Rate=0.100, Error=0.955
# Epoch=838, Learning Rate=0.100, Error=0.955
# Epoch=839, Learning Rate=0.100, Error=0.955
# Epoch=840, Learning Rate=0.100, Error=0.955
# Epoch=841, Learning Rate=0.100, Error=0.954
# Epoch=842, Learning Rate=0.100, Error=0.954
# Epoch=843, Learning Rate=0.100, Error=0.954
# Epoch=844, Learning Rate=0.100, Error=0.954
# Epoch=845, Learning Rate=0.100, Error=0.954
# Epoch=846, Learning Rate=0.100, Error=0.954
# Epoch=847, Learning Rate=0.100, Error=0.953
# Epoch=848, Learning Rate=0.100, Error=0.953
# Epoch=849, Learning Rate=0.100, Error=0.953
# Epoch=850, Learning Rate=0.100, Error=0.953
# Epoch=851, Learning Rate=0.100, Error=0.953
# Epoch=852, Learning Rate=0.100, Error=0.952
# Epoch=853, Learning Rate=0.100, Error=0.952
# Epoch=854, Learning Rate=0.100, Error=0.952
# Epoch=855, Learning Rate=0.100, Error=0.952
# Epoch=856, Learning Rate=0.100, Error=0.952
# Epoch=857, Learning Rate=0.100, Error=0.951
# Epoch=858, Learning Rate=0.100, Error=0.951
# Epoch=859, Learning Rate=0.100, Error=0.951
# Epoch=860, Learning Rate=0.100, Error=0.951
# Epoch=861, Learning Rate=0.100, Error=0.950
# Epoch=862, Learning Rate=0.100, Error=0.950
# Epoch=863, Learning Rate=0.100, Error=0.950
# Epoch=864, Learning Rate=0.100, Error=0.950
# Epoch=865, Learning Rate=0.100, Error=0.950
# Epoch=866, Learning Rate=0.100, Error=0.949
# Epoch=867, Learning Rate=0.100, Error=0.949
# Epoch=868, Learning Rate=0.100, Error=0.949
# Epoch=869, Learning Rate=0.100, Error=0.949
# Epoch=870, Learning Rate=0.100, Error=0.949
# Epoch=871, Learning Rate=0.100, Error=0.948
# Epoch=872, Learning Rate=0.100, Error=0.948
# Epoch=873, Learning Rate=0.100, Error=0.948
# Epoch=874, Learning Rate=0.100, Error=0.948
# Epoch=875, Learning Rate=0.100, Error=0.948
# Epoch=876, Learning Rate=0.100, Error=0.947
# Epoch=877, Learning Rate=0.100, Error=0.947
# Epoch=878, Learning Rate=0.100, Error=0.947
# Epoch=879, Learning Rate=0.100, Error=0.947
# Epoch=880, Learning Rate=0.100, Error=0.946
# Epoch=881, Learning Rate=0.100, Error=0.946
# Epoch=882, Learning Rate=0.100, Error=0.946
# Epoch=883, Learning Rate=0.100, Error=0.946
# Epoch=884, Learning Rate=0.100, Error=0.946
# Epoch=885, Learning Rate=0.100, Error=0.945
# Epoch=886, Learning Rate=0.100, Error=0.945
# Epoch=887, Learning Rate=0.100, Error=0.945
# Epoch=888, Learning Rate=0.100, Error=0.945
# Epoch=889, Learning Rate=0.100, Error=0.944
# Epoch=890, Learning Rate=0.100, Error=0.944
# Epoch=891, Learning Rate=0.100, Error=0.944
# Epoch=892, Learning Rate=0.100, Error=0.944
# Epoch=893, Learning Rate=0.100, Error=0.944
# Epoch=894, Learning Rate=0.100, Error=0.943
# Epoch=895, Learning Rate=0.100, Error=0.943
# Epoch=896, Learning Rate=0.100, Error=0.943
# Epoch=897, Learning Rate=0.100, Error=0.943
# Epoch=898, Learning Rate=0.100, Error=0.942
# Epoch=899, Learning Rate=0.100, Error=0.942
# Epoch=900, Learning Rate=0.100, Error=0.942
# Epoch=901, Learning Rate=0.100, Error=0.942
# Epoch=902, Learning Rate=0.100, Error=0.942
# Epoch=903, Learning Rate=0.100, Error=0.941
# Epoch=904, Learning Rate=0.100, Error=0.941
# Epoch=905, Learning Rate=0.100, Error=0.941
# Epoch=906, Learning Rate=0.100, Error=0.941
# Epoch=907, Learning Rate=0.100, Error=0.940
# Epoch=908, Learning Rate=0.100, Error=0.940
# Epoch=909, Learning Rate=0.100, Error=0.940
# Epoch=910, Learning Rate=0.100, Error=0.940
# Epoch=911, Learning Rate=0.100, Error=0.939
# Epoch=912, Learning Rate=0.100, Error=0.939
# Epoch=913, Learning Rate=0.100, Error=0.939
# Epoch=914, Learning Rate=0.100, Error=0.939
# Epoch=915, Learning Rate=0.100, Error=0.938
# Epoch=916, Learning Rate=0.100, Error=0.938
# Epoch=917, Learning Rate=0.100, Error=0.938
# Epoch=918, Learning Rate=0.100, Error=0.938
# Epoch=919, Learning Rate=0.100, Error=0.938
# Epoch=920, Learning Rate=0.100, Error=0.937
# Epoch=921, Learning Rate=0.100, Error=0.937
# Epoch=922, Learning Rate=0.100, Error=0.937
# Epoch=923, Learning Rate=0.100, Error=0.937
# Epoch=924, Learning Rate=0.100, Error=0.936
# Epoch=925, Learning Rate=0.100, Error=0.936
# Epoch=926, Learning Rate=0.100, Error=0.936
# Epoch=927, Learning Rate=0.100, Error=0.936
# Epoch=928, Learning Rate=0.100, Error=0.935
# Epoch=929, Learning Rate=0.100, Error=0.935
# Epoch=930, Learning Rate=0.100, Error=0.935
# Epoch=931, Learning Rate=0.100, Error=0.935
# Epoch=932, Learning Rate=0.100, Error=0.934
# Epoch=933, Learning Rate=0.100, Error=0.934
# Epoch=934, Learning Rate=0.100, Error=0.934
# Epoch=935, Learning Rate=0.100, Error=0.934
# Epoch=936, Learning Rate=0.100, Error=0.933
# Epoch=937, Learning Rate=0.100, Error=0.933
# Epoch=938, Learning Rate=0.100, Error=0.933
# Epoch=939, Learning Rate=0.100, Error=0.933
# Epoch=940, Learning Rate=0.100, Error=0.932
# Epoch=941, Learning Rate=0.100, Error=0.932
# Epoch=942, Learning Rate=0.100, Error=0.932
# Epoch=943, Learning Rate=0.100, Error=0.931
# Epoch=944, Learning Rate=0.100, Error=0.931
# Epoch=945, Learning Rate=0.100, Error=0.931
# Epoch=946, Learning Rate=0.100, Error=0.931
# Epoch=947, Learning Rate=0.100, Error=0.930
# Epoch=948, Learning Rate=0.100, Error=0.930
# Epoch=949, Learning Rate=0.100, Error=0.930
# Epoch=950, Learning Rate=0.100, Error=0.930
# Epoch=951, Learning Rate=0.100, Error=0.929
# Epoch=952, Learning Rate=0.100, Error=0.929
# Epoch=953, Learning Rate=0.100, Error=0.929
# Epoch=954, Learning Rate=0.100, Error=0.929
# Epoch=955, Learning Rate=0.100, Error=0.928
# Epoch=956, Learning Rate=0.100, Error=0.928
# Epoch=957, Learning Rate=0.100, Error=0.928
# Epoch=958, Learning Rate=0.100, Error=0.928
# Epoch=959, Learning Rate=0.100, Error=0.927
# Epoch=960, Learning Rate=0.100, Error=0.927
# Epoch=961, Learning Rate=0.100, Error=0.927
# Epoch=962, Learning Rate=0.100, Error=0.926
# Epoch=963, Learning Rate=0.100, Error=0.926
# Epoch=964, Learning Rate=0.100, Error=0.926
# Epoch=965, Learning Rate=0.100, Error=0.926
# Epoch=966, Learning Rate=0.100, Error=0.925
# Epoch=967, Learning Rate=0.100, Error=0.925
# Epoch=968, Learning Rate=0.100, Error=0.925
# Epoch=969, Learning Rate=0.100, Error=0.924
# Epoch=970, Learning Rate=0.100, Error=0.924
# Epoch=971, Learning Rate=0.100, Error=0.924
# Epoch=972, Learning Rate=0.100, Error=0.924
# Epoch=973, Learning Rate=0.100, Error=0.923
# Epoch=974, Learning Rate=0.100, Error=0.923
# Epoch=975, Learning Rate=0.100, Error=0.923
# Epoch=976, Learning Rate=0.100, Error=0.923
# Epoch=977, Learning Rate=0.100, Error=0.922
# Epoch=978, Learning Rate=0.100, Error=0.922
# Epoch=979, Learning Rate=0.100, Error=0.922
# Epoch=980, Learning Rate=0.100, Error=0.921
# Epoch=981, Learning Rate=0.100, Error=0.921
# Epoch=982, Learning Rate=0.100, Error=0.921
# Epoch=983, Learning Rate=0.100, Error=0.921
# Epoch=984, Learning Rate=0.100, Error=0.920
# Epoch=985, Learning Rate=0.100, Error=0.920
# Epoch=986, Learning Rate=0.100, Error=0.920
# Epoch=987, Learning Rate=0.100, Error=0.919
# Epoch=988, Learning Rate=0.100, Error=0.919
# Epoch=989, Learning Rate=0.100, Error=0.919
# Epoch=990, Learning Rate=0.100, Error=0.918
# Epoch=991, Learning Rate=0.100, Error=0.918
# Epoch=992, Learning Rate=0.100, Error=0.918
# Epoch=993, Learning Rate=0.100, Error=0.918
# Epoch=994, Learning Rate=0.100, Error=0.917
# Epoch=995, Learning Rate=0.100, Error=0.917
# Epoch=996, Learning Rate=0.100, Error=0.917
# Epoch=997, Learning Rate=0.100, Error=0.916
# Epoch=998, Learning Rate=0.100, Error=0.916
# Epoch=999, Learning Rate=0.100, Error=0.916
# Epoch=1000, Learning Rate=0.100, Error=0.915
# Epoch=1001, Learning Rate=0.100, Error=0.915
# Epoch=1002, Learning Rate=0.100, Error=0.915
# Epoch=1003, Learning Rate=0.100, Error=0.915
# Epoch=1004, Learning Rate=0.100, Error=0.914
# Epoch=1005, Learning Rate=0.100, Error=0.914
# Epoch=1006, Learning Rate=0.100, Error=0.914
# Epoch=1007, Learning Rate=0.100, Error=0.913
# Epoch=1008, Learning Rate=0.100, Error=0.913
# Epoch=1009, Learning Rate=0.100, Error=0.913
# Epoch=1010, Learning Rate=0.100, Error=0.912
# Epoch=1011, Learning Rate=0.100, Error=0.912
# Epoch=1012, Learning Rate=0.100, Error=0.912
# Epoch=1013, Learning Rate=0.100, Error=0.911
# Epoch=1014, Learning Rate=0.100, Error=0.911
# Epoch=1015, Learning Rate=0.100, Error=0.911
# Epoch=1016, Learning Rate=0.100, Error=0.911
# Epoch=1017, Learning Rate=0.100, Error=0.910
# Epoch=1018, Learning Rate=0.100, Error=0.910
# Epoch=1019, Learning Rate=0.100, Error=0.910
# Epoch=1020, Learning Rate=0.100, Error=0.909
# Epoch=1021, Learning Rate=0.100, Error=0.909
# Epoch=1022, Learning Rate=0.100, Error=0.909
# Epoch=1023, Learning Rate=0.100, Error=0.908
# Epoch=1024, Learning Rate=0.100, Error=0.908
# Epoch=1025, Learning Rate=0.100, Error=0.908
# Epoch=1026, Learning Rate=0.100, Error=0.907
# Epoch=1027, Learning Rate=0.100, Error=0.907
# Epoch=1028, Learning Rate=0.100, Error=0.907
# Epoch=1029, Learning Rate=0.100, Error=0.906
# Epoch=1030, Learning Rate=0.100, Error=0.906
# Epoch=1031, Learning Rate=0.100, Error=0.906
# Epoch=1032, Learning Rate=0.100, Error=0.905
# Epoch=1033, Learning Rate=0.100, Error=0.905
# Epoch=1034, Learning Rate=0.100, Error=0.905
# Epoch=1035, Learning Rate=0.100, Error=0.904
# Epoch=1036, Learning Rate=0.100, Error=0.904
# Epoch=1037, Learning Rate=0.100, Error=0.904
# Epoch=1038, Learning Rate=0.100, Error=0.903
# Epoch=1039, Learning Rate=0.100, Error=0.903
# Epoch=1040, Learning Rate=0.100, Error=0.903
# Epoch=1041, Learning Rate=0.100, Error=0.902
# Epoch=1042, Learning Rate=0.100, Error=0.902
# Epoch=1043, Learning Rate=0.100, Error=0.902
# Epoch=1044, Learning Rate=0.100, Error=0.901
# Epoch=1045, Learning Rate=0.100, Error=0.901
# Epoch=1046, Learning Rate=0.100, Error=0.901
# Epoch=1047, Learning Rate=0.100, Error=0.900
# Epoch=1048, Learning Rate=0.100, Error=0.900
# Epoch=1049, Learning Rate=0.100, Error=0.900
# Epoch=1050, Learning Rate=0.100, Error=0.899
# Epoch=1051, Learning Rate=0.100, Error=0.899
# Epoch=1052, Learning Rate=0.100, Error=0.899
# Epoch=1053, Learning Rate=0.100, Error=0.898
# Epoch=1054, Learning Rate=0.100, Error=0.898
# Epoch=1055, Learning Rate=0.100, Error=0.898
# Epoch=1056, Learning Rate=0.100, Error=0.897
# Epoch=1057, Learning Rate=0.100, Error=0.897
# Epoch=1058, Learning Rate=0.100, Error=0.896
# Epoch=1059, Learning Rate=0.100, Error=0.896
# Epoch=1060, Learning Rate=0.100, Error=0.896
# Epoch=1061, Learning Rate=0.100, Error=0.895
# Epoch=1062, Learning Rate=0.100, Error=0.895
# Epoch=1063, Learning Rate=0.100, Error=0.895
# Epoch=1064, Learning Rate=0.100, Error=0.894
# Epoch=1065, Learning Rate=0.100, Error=0.894
# Epoch=1066, Learning Rate=0.100, Error=0.894
# Epoch=1067, Learning Rate=0.100, Error=0.893
# Epoch=1068, Learning Rate=0.100, Error=0.893
# Epoch=1069, Learning Rate=0.100, Error=0.893
# Epoch=1070, Learning Rate=0.100, Error=0.892
# Epoch=1071, Learning Rate=0.100, Error=0.892
# Epoch=1072, Learning Rate=0.100, Error=0.891
# Epoch=1073, Learning Rate=0.100, Error=0.891
# Epoch=1074, Learning Rate=0.100, Error=0.891
# Epoch=1075, Learning Rate=0.100, Error=0.890
# Epoch=1076, Learning Rate=0.100, Error=0.890
# Epoch=1077, Learning Rate=0.100, Error=0.890
# Epoch=1078, Learning Rate=0.100, Error=0.889
# Epoch=1079, Learning Rate=0.100, Error=0.889
# Epoch=1080, Learning Rate=0.100, Error=0.889
# Epoch=1081, Learning Rate=0.100, Error=0.888
# Epoch=1082, Learning Rate=0.100, Error=0.888
# Epoch=1083, Learning Rate=0.100, Error=0.887
# Epoch=1084, Learning Rate=0.100, Error=0.887
# Epoch=1085, Learning Rate=0.100, Error=0.887
# ...
# Epoch=4661, Learning Rate=0.100, Error=0.021
# Epoch=4662, Learning Rate=0.100, Error=0.021
# Epoch=4663, Learning Rate=0.100, Error=0.021
# Epoch=4664, Learning Rate=0.100, Error=0.021
# Epoch=4665, Learning Rate=0.100, Error=0.021
# Epoch=4666, Learning Rate=0.100, Error=0.021
# Epoch=4667, Learning Rate=0.100, Error=0.021
# Epoch=4668, Learning Rate=0.100, Error=0.021
# Epoch=4669, Learning Rate=0.100, Error=0.021
# Epoch=4670, Learning Rate=0.100, Error=0.021
# Epoch=4671, Learning Rate=0.100, Error=0.021
# Epoch=4672, Learning Rate=0.100, Error=0.021
# Epoch=4673, Learning Rate=0.100, Error=0.021
# Epoch=4674, Learning Rate=0.100, Error=0.021
# Epoch=4675, Learning Rate=0.100, Error=0.021
# Epoch=4676, Learning Rate=0.100, Error=0.021
# Epoch=4677, Learning Rate=0.100, Error=0.021
# Epoch=4678, Learning Rate=0.100, Error=0.021
# Epoch=4679, Learning Rate=0.100, Error=0.021
# Epoch=4680, Learning Rate=0.100, Error=0.021
# Epoch=4681, Learning Rate=0.100, Error=0.021
# Epoch=4682, Learning Rate=0.100, Error=0.021
# Epoch=4683, Learning Rate=0.100, Error=0.021
# Epoch=4684, Learning Rate=0.100, Error=0.021
# Epoch=4685, Learning Rate=0.100, Error=0.021
# Epoch=4686, Learning Rate=0.100, Error=0.021
# Epoch=4687, Learning Rate=0.100, Error=0.021
# Epoch=4688, Learning Rate=0.100, Error=0.021
# Epoch=4689, Learning Rate=0.100, Error=0.021
# Epoch=4690, Learning Rate=0.100, Error=0.021
# Epoch=4691, Learning Rate=0.100, Error=0.021
# Epoch=4692, Learning Rate=0.100, Error=0.021
# Epoch=4693, Learning Rate=0.100, Error=0.021
# Epoch=4694, Learning Rate=0.100, Error=0.021
# Epoch=4695, Learning Rate=0.100, Error=0.021
# Epoch=4696, Learning Rate=0.100, Error=0.021
# Epoch=4697, Learning Rate=0.100, Error=0.021
# Epoch=4698, Learning Rate=0.100, Error=0.021
# Epoch=4699, Learning Rate=0.100, Error=0.021
# Epoch=4700, Learning Rate=0.100, Error=0.021
# Epoch=4701, Learning Rate=0.100, Error=0.021
# Epoch=4702, Learning Rate=0.100, Error=0.021
# Epoch=4703, Learning Rate=0.100, Error=0.021
# Epoch=4704, Learning Rate=0.100, Error=0.021
# Epoch=4705, Learning Rate=0.100, Error=0.021
# Epoch=4706, Learning Rate=0.100, Error=0.020
# Epoch=4707, Learning Rate=0.100, Error=0.020
# Epoch=4708, Learning Rate=0.100, Error=0.020
# Epoch=4709, Learning Rate=0.100, Error=0.020
# Epoch=4710, Learning Rate=0.100, Error=0.020
# Epoch=4711, Learning Rate=0.100, Error=0.020
# Epoch=4712, Learning Rate=0.100, Error=0.020
# Epoch=4713, Learning Rate=0.100, Error=0.020
# Epoch=4714, Learning Rate=0.100, Error=0.020
# Epoch=4715, Learning Rate=0.100, Error=0.020
# Epoch=4716, Learning Rate=0.100, Error=0.020
# Epoch=4717, Learning Rate=0.100, Error=0.020
# Epoch=4718, Learning Rate=0.100, Error=0.020
# Epoch=4719, Learning Rate=0.100, Error=0.020
# Epoch=4720, Learning Rate=0.100, Error=0.020
# Epoch=4721, Learning Rate=0.100, Error=0.020
# Epoch=4722, Learning Rate=0.100, Error=0.020
# Epoch=4723, Learning Rate=0.100, Error=0.020
# Epoch=4724, Learning Rate=0.100, Error=0.020
# Epoch=4725, Learning Rate=0.100, Error=0.020
# Epoch=4726, Learning Rate=0.100, Error=0.020
# Epoch=4727, Learning Rate=0.100, Error=0.020
# Epoch=4728, Learning Rate=0.100, Error=0.020
# Epoch=4729, Learning Rate=0.100, Error=0.020
# Epoch=4730, Learning Rate=0.100, Error=0.020
# Epoch=4731, Learning Rate=0.100, Error=0.020
# Epoch=4732, Learning Rate=0.100, Error=0.020
# Epoch=4733, Learning Rate=0.100, Error=0.020
# Epoch=4734, Learning Rate=0.100, Error=0.020
# Epoch=4735, Learning Rate=0.100, Error=0.020
# Epoch=4736, Learning Rate=0.100, Error=0.020
# Epoch=4737, Learning Rate=0.100, Error=0.020
# Epoch=4738, Learning Rate=0.100, Error=0.020
# Epoch=4739, Learning Rate=0.100, Error=0.020
# Epoch=4740, Learning Rate=0.100, Error=0.020
# Epoch=4741, Learning Rate=0.100, Error=0.020
# Epoch=4742, Learning Rate=0.100, Error=0.020
# Epoch=4743, Learning Rate=0.100, Error=0.020
# Epoch=4744, Learning Rate=0.100, Error=0.020
# Epoch=4745, Learning Rate=0.100, Error=0.020
# Epoch=4746, Learning Rate=0.100, Error=0.020
# Epoch=4747, Learning Rate=0.100, Error=0.020
# Epoch=4748, Learning Rate=0.100, Error=0.020
# Epoch=4749, Learning Rate=0.100, Error=0.020
# Epoch=4750, Learning Rate=0.100, Error=0.020
# Epoch=4751, Learning Rate=0.100, Error=0.020
# Epoch=4752, Learning Rate=0.100, Error=0.020
# Epoch=4753, Learning Rate=0.100, Error=0.020
# Epoch=4754, Learning Rate=0.100, Error=0.020
# Epoch=4755, Learning Rate=0.100, Error=0.020
# Epoch=4756, Learning Rate=0.100, Error=0.020
# Epoch=4757, Learning Rate=0.100, Error=0.020
# Epoch=4758, Learning Rate=0.100, Error=0.020
# Epoch=4759, Learning Rate=0.100, Error=0.020
# Epoch=4760, Learning Rate=0.100, Error=0.020
# Epoch=4761, Learning Rate=0.100, Error=0.020
# Epoch=4762, Learning Rate=0.100, Error=0.020
# Epoch=4763, Learning Rate=0.100, Error=0.020
# Epoch=4764, Learning Rate=0.100, Error=0.020
# Epoch=4765, Learning Rate=0.100, Error=0.020
# Epoch=4766, Learning Rate=0.100, Error=0.020
# Epoch=4767, Learning Rate=0.100, Error=0.020
# Epoch=4768, Learning Rate=0.100, Error=0.020
# Epoch=4769, Learning Rate=0.100, Error=0.020
# Epoch=4770, Learning Rate=0.100, Error=0.020
# Epoch=4771, Learning Rate=0.100, Error=0.020
# Epoch=4772, Learning Rate=0.100, Error=0.020
# Epoch=4773, Learning Rate=0.100, Error=0.020
# Epoch=4774, Learning Rate=0.100, Error=0.020
# Epoch=4775, Learning Rate=0.100, Error=0.020
# Epoch=4776, Learning Rate=0.100, Error=0.020
# Epoch=4777, Learning Rate=0.100, Error=0.020
# Epoch=4778, Learning Rate=0.100, Error=0.020
# Epoch=4779, Learning Rate=0.100, Error=0.020
# Epoch=4780, Learning Rate=0.100, Error=0.020
# Epoch=4781, Learning Rate=0.100, Error=0.020
# Epoch=4782, Learning Rate=0.100, Error=0.020
# Epoch=4783, Learning Rate=0.100, Error=0.020
# Epoch=4784, Learning Rate=0.100, Error=0.020
# Epoch=4785, Learning Rate=0.100, Error=0.020
# Epoch=4786, Learning Rate=0.100, Error=0.020
# Epoch=4787, Learning Rate=0.100, Error=0.020
# Epoch=4788, Learning Rate=0.100, Error=0.020
# Epoch=4789, Learning Rate=0.100, Error=0.020
# Epoch=4790, Learning Rate=0.100, Error=0.020
# Epoch=4791, Learning Rate=0.100, Error=0.020
# Epoch=4792, Learning Rate=0.100, Error=0.020
# Epoch=4793, Learning Rate=0.100, Error=0.020
# Epoch=4794, Learning Rate=0.100, Error=0.020
# Epoch=4795, Learning Rate=0.100, Error=0.020
# Epoch=4796, Learning Rate=0.100, Error=0.020
# Epoch=4797, Learning Rate=0.100, Error=0.020
# Epoch=4798, Learning Rate=0.100, Error=0.020
# Epoch=4799, Learning Rate=0.100, Error=0.020
# Epoch=4800, Learning Rate=0.100, Error=0.020
# Epoch=4801, Learning Rate=0.100, Error=0.020
# Epoch=4802, Learning Rate=0.100, Error=0.020
# Epoch=4803, Learning Rate=0.100, Error=0.020
# Epoch=4804, Learning Rate=0.100, Error=0.020
# Epoch=4805, Learning Rate=0.100, Error=0.020
# Epoch=4806, Learning Rate=0.100, Error=0.020
# Epoch=4807, Learning Rate=0.100, Error=0.020
# Epoch=4808, Learning Rate=0.100, Error=0.020
# Epoch=4809, Learning Rate=0.100, Error=0.020
# Epoch=4810, Learning Rate=0.100, Error=0.020
# Epoch=4811, Learning Rate=0.100, Error=0.020
# Epoch=4812, Learning Rate=0.100, Error=0.020
# Epoch=4813, Learning Rate=0.100, Error=0.020
# Epoch=4814, Learning Rate=0.100, Error=0.020
# Epoch=4815, Learning Rate=0.100, Error=0.019
# Epoch=4816, Learning Rate=0.100, Error=0.019
# Epoch=4817, Learning Rate=0.100, Error=0.019
# Epoch=4818, Learning Rate=0.100, Error=0.019
# Epoch=4819, Learning Rate=0.100, Error=0.019
# Epoch=4820, Learning Rate=0.100, Error=0.019
# Epoch=4821, Learning Rate=0.100, Error=0.019
# Epoch=4822, Learning Rate=0.100, Error=0.019
# Epoch=4823, Learning Rate=0.100, Error=0.019
# Epoch=4824, Learning Rate=0.100, Error=0.019
# Epoch=4825, Learning Rate=0.100, Error=0.019
# Epoch=4826, Learning Rate=0.100, Error=0.019
# Epoch=4827, Learning Rate=0.100, Error=0.019
# Epoch=4828, Learning Rate=0.100, Error=0.019
# Epoch=4829, Learning Rate=0.100, Error=0.019
# Epoch=4830, Learning Rate=0.100, Error=0.019
# Epoch=4831, Learning Rate=0.100, Error=0.019
# Epoch=4832, Learning Rate=0.100, Error=0.019
# Epoch=4833, Learning Rate=0.100, Error=0.019
# Epoch=4834, Learning Rate=0.100, Error=0.019
# Epoch=4835, Learning Rate=0.100, Error=0.019
# Epoch=4836, Learning Rate=0.100, Error=0.019
# Epoch=4837, Learning Rate=0.100, Error=0.019
# Epoch=4838, Learning Rate=0.100, Error=0.019
# Epoch=4839, Learning Rate=0.100, Error=0.019
# Epoch=4840, Learning Rate=0.100, Error=0.019
# Epoch=4841, Learning Rate=0.100, Error=0.019
# Epoch=4842, Learning Rate=0.100, Error=0.019
# Epoch=4843, Learning Rate=0.100, Error=0.019
# Epoch=4844, Learning Rate=0.100, Error=0.019
# Epoch=4845, Learning Rate=0.100, Error=0.019
# Epoch=4846, Learning Rate=0.100, Error=0.019
# Epoch=4847, Learning Rate=0.100, Error=0.019
# Epoch=4848, Learning Rate=0.100, Error=0.019
# Epoch=4849, Learning Rate=0.100, Error=0.019
# Epoch=4850, Learning Rate=0.100, Error=0.019
# Epoch=4851, Learning Rate=0.100, Error=0.019
# Epoch=4852, Learning Rate=0.100, Error=0.019
# Epoch=4853, Learning Rate=0.100, Error=0.019
# Epoch=4854, Learning Rate=0.100, Error=0.019
# Epoch=4855, Learning Rate=0.100, Error=0.019
# Epoch=4856, Learning Rate=0.100, Error=0.019
# Epoch=4857, Learning Rate=0.100, Error=0.019
# Epoch=4858, Learning Rate=0.100, Error=0.019
# Epoch=4859, Learning Rate=0.100, Error=0.019
# Epoch=4860, Learning Rate=0.100, Error=0.019
# Epoch=4861, Learning Rate=0.100, Error=0.019
# Epoch=4862, Learning Rate=0.100, Error=0.019
# Epoch=4863, Learning Rate=0.100, Error=0.019
# Epoch=4864, Learning Rate=0.100, Error=0.019
# Epoch=4865, Learning Rate=0.100, Error=0.019
# Epoch=4866, Learning Rate=0.100, Error=0.019
# Epoch=4867, Learning Rate=0.100, Error=0.019
# Epoch=4868, Learning Rate=0.100, Error=0.019
# Epoch=4869, Learning Rate=0.100, Error=0.019
# Epoch=4870, Learning Rate=0.100, Error=0.019
# Epoch=4871, Learning Rate=0.100, Error=0.019
# Epoch=4872, Learning Rate=0.100, Error=0.019
# Epoch=4873, Learning Rate=0.100, Error=0.019
# Epoch=4874, Learning Rate=0.100, Error=0.019
# Epoch=4875, Learning Rate=0.100, Error=0.019
# Epoch=4876, Learning Rate=0.100, Error=0.019
# Epoch=4877, Learning Rate=0.100, Error=0.019
# Epoch=4878, Learning Rate=0.100, Error=0.019
# Epoch=4879, Learning Rate=0.100, Error=0.019
# Epoch=4880, Learning Rate=0.100, Error=0.019
# Epoch=4881, Learning Rate=0.100, Error=0.019
# Epoch=4882, Learning Rate=0.100, Error=0.019
# Epoch=4883, Learning Rate=0.100, Error=0.019
# Epoch=4884, Learning Rate=0.100, Error=0.019
# Epoch=4885, Learning Rate=0.100, Error=0.019
# Epoch=4886, Learning Rate=0.100, Error=0.019
# Epoch=4887, Learning Rate=0.100, Error=0.019
# Epoch=4888, Learning Rate=0.100, Error=0.019
# Epoch=4889, Learning Rate=0.100, Error=0.019
# Epoch=4890, Learning Rate=0.100, Error=0.019
# Epoch=4891, Learning Rate=0.100, Error=0.019
# Epoch=4892, Learning Rate=0.100, Error=0.019
# Epoch=4893, Learning Rate=0.100, Error=0.019
# Epoch=4894, Learning Rate=0.100, Error=0.019
# Epoch=4895, Learning Rate=0.100, Error=0.019
# Epoch=4896, Learning Rate=0.100, Error=0.019
# Epoch=4897, Learning Rate=0.100, Error=0.019
# Epoch=4898, Learning Rate=0.100, Error=0.019
# Epoch=4899, Learning Rate=0.100, Error=0.019
# Epoch=4900, Learning Rate=0.100, Error=0.019
# Epoch=4901, Learning Rate=0.100, Error=0.019
# Epoch=4902, Learning Rate=0.100, Error=0.019
# Epoch=4903, Learning Rate=0.100, Error=0.019
# Epoch=4904, Learning Rate=0.100, Error=0.019
# Epoch=4905, Learning Rate=0.100, Error=0.019
# Epoch=4906, Learning Rate=0.100, Error=0.019
# Epoch=4907, Learning Rate=0.100, Error=0.019
# Epoch=4908, Learning Rate=0.100, Error=0.019
# Epoch=4909, Learning Rate=0.100, Error=0.019
# Epoch=4910, Learning Rate=0.100, Error=0.019
# Epoch=4911, Learning Rate=0.100, Error=0.019
# Epoch=4912, Learning Rate=0.100, Error=0.019
# Epoch=4913, Learning Rate=0.100, Error=0.019
# Epoch=4914, Learning Rate=0.100, Error=0.019
# Epoch=4915, Learning Rate=0.100, Error=0.019
# Epoch=4916, Learning Rate=0.100, Error=0.019
# Epoch=4917, Learning Rate=0.100, Error=0.019
# Epoch=4918, Learning Rate=0.100, Error=0.019
# Epoch=4919, Learning Rate=0.100, Error=0.019
# Epoch=4920, Learning Rate=0.100, Error=0.019
# Epoch=4921, Learning Rate=0.100, Error=0.019
# Epoch=4922, Learning Rate=0.100, Error=0.019
# Epoch=4923, Learning Rate=0.100, Error=0.019
# Epoch=4924, Learning Rate=0.100, Error=0.019
# Epoch=4925, Learning Rate=0.100, Error=0.019
# Epoch=4926, Learning Rate=0.100, Error=0.019
# Epoch=4927, Learning Rate=0.100, Error=0.019
# Epoch=4928, Learning Rate=0.100, Error=0.019
# Epoch=4929, Learning Rate=0.100, Error=0.019
# Epoch=4930, Learning Rate=0.100, Error=0.019
# Epoch=4931, Learning Rate=0.100, Error=0.019
# Epoch=4932, Learning Rate=0.100, Error=0.019
# Epoch=4933, Learning Rate=0.100, Error=0.019
# Epoch=4934, Learning Rate=0.100, Error=0.019
# Epoch=4935, Learning Rate=0.100, Error=0.018
# Epoch=4936, Learning Rate=0.100, Error=0.018
# Epoch=4937, Learning Rate=0.100, Error=0.018
# Epoch=4938, Learning Rate=0.100, Error=0.018
# Epoch=4939, Learning Rate=0.100, Error=0.018
# Epoch=4940, Learning Rate=0.100, Error=0.018
# Epoch=4941, Learning Rate=0.100, Error=0.018
# Epoch=4942, Learning Rate=0.100, Error=0.018
# Epoch=4943, Learning Rate=0.100, Error=0.018
# Epoch=4944, Learning Rate=0.100, Error=0.018
# Epoch=4945, Learning Rate=0.100, Error=0.018
# Epoch=4946, Learning Rate=0.100, Error=0.018
# Epoch=4947, Learning Rate=0.100, Error=0.018
# Epoch=4948, Learning Rate=0.100, Error=0.018
# Epoch=4949, Learning Rate=0.100, Error=0.018
# Epoch=4950, Learning Rate=0.100, Error=0.018
# Epoch=4951, Learning Rate=0.100, Error=0.018
# Epoch=4952, Learning Rate=0.100, Error=0.018
# Epoch=4953, Learning Rate=0.100, Error=0.018
# Epoch=4954, Learning Rate=0.100, Error=0.018
# Epoch=4955, Learning Rate=0.100, Error=0.018
# Epoch=4956, Learning Rate=0.100, Error=0.018
# Epoch=4957, Learning Rate=0.100, Error=0.018
# Epoch=4958, Learning Rate=0.100, Error=0.018
# Epoch=4959, Learning Rate=0.100, Error=0.018
# Epoch=4960, Learning Rate=0.100, Error=0.018
# Epoch=4961, Learning Rate=0.100, Error=0.018
# Epoch=4962, Learning Rate=0.100, Error=0.018
# Epoch=4963, Learning Rate=0.100, Error=0.018
# Epoch=4964, Learning Rate=0.100, Error=0.018
# Epoch=4965, Learning Rate=0.100, Error=0.018
# Epoch=4966, Learning Rate=0.100, Error=0.018
# Epoch=4967, Learning Rate=0.100, Error=0.018
# Epoch=4968, Learning Rate=0.100, Error=0.018
# Epoch=4969, Learning Rate=0.100, Error=0.018
# Epoch=4970, Learning Rate=0.100, Error=0.018
# Epoch=4971, Learning Rate=0.100, Error=0.018
# Epoch=4972, Learning Rate=0.100, Error=0.018
# Epoch=4973, Learning Rate=0.100, Error=0.018
# Epoch=4974, Learning Rate=0.100, Error=0.018
# Epoch=4975, Learning Rate=0.100, Error=0.018
# Epoch=4976, Learning Rate=0.100, Error=0.018
# Epoch=4977, Learning Rate=0.100, Error=0.018
# Epoch=4978, Learning Rate=0.100, Error=0.018
# Epoch=4979, Learning Rate=0.100, Error=0.018
# Epoch=4980, Learning Rate=0.100, Error=0.018
# Epoch=4981, Learning Rate=0.100, Error=0.018
# Epoch=4982, Learning Rate=0.100, Error=0.018
# Epoch=4983, Learning Rate=0.100, Error=0.018
# Epoch=4984, Learning Rate=0.100, Error=0.018
# Epoch=4985, Learning Rate=0.100, Error=0.018
# Epoch=4986, Learning Rate=0.100, Error=0.018
# Epoch=4987, Learning Rate=0.100, Error=0.018
# Epoch=4988, Learning Rate=0.100, Error=0.018
# Epoch=4989, Learning Rate=0.100, Error=0.018
# Epoch=4990, Learning Rate=0.100, Error=0.018
# Epoch=4991, Learning Rate=0.100, Error=0.018
# Epoch=4992, Learning Rate=0.100, Error=0.018
# Epoch=4993, Learning Rate=0.100, Error=0.018
# Epoch=4994, Learning Rate=0.100, Error=0.018
# Epoch=4995, Learning Rate=0.100, Error=0.018
# Epoch=4996, Learning Rate=0.100, Error=0.018
# Epoch=4997, Learning Rate=0.100, Error=0.018
# Epoch=4998, Learning Rate=0.100, Error=0.018
# Epoch=4999, Learning Rate=0.100, Error=0.018
# Epoch=5000, Learning Rate=0.100, Error=0.018
#
# Final weights
#
# ======= Hidden layer =======
#
# Neuron  1
# weights   [5.564400873246104, -0.7625977573215473, -1.7753258577384965]
# output   0.29103411074088203
#
#
# Neuron  2
# weights   [-3.8398637941009905, 0.4634998604537811, 1.078332868179256]
# output   0.6103536078313122
#
#
# Neuron  3
# weights   [-5.290374922026391, 0.01401025379140653, 1.8800341793046895]
# output   0.6953776652483354
#
#
# ======= Output layer =======
#
# Neuron  1
# weights   [-4.697721739008186, 2.6992366999341444, 4.101000904514553, -0.4640549631748329]
# output   0.9350641841410314
#
#
# Neuron  2
# weights   [4.4939714352122895, -2.9757442179979146, -4.035897074124544, 0.6640809296490285]
# output   0.06599150067169088
